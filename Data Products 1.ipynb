# %%
# Import library yang diperlukan
import os
import pandas as pd

# Bikin variable pathnya biar gampang dipanggil
source_folder_path = r"C:\Users\N I T R O   5\Documents\Bootcamps\Purwadhika\Capstone\data_sources\data_sources\data_products"
output_folder_path = r"D:\PURWA\1"

# %%
# Fungsi buat extract data dari CSVnya dan di upload ke dataframe
def extract_data(file_path, delete_index=True):
    df = pd.read_csv(file_path)
    if delete_index:
        df.reset_index(drop=True, inplace=True)  # Remove index if required
    return df

# %%
# Fungsi buat transformasi data
def transform_data(df):
    # Delete simbol currency nya jadi cuma angka aja buat kolom actual price
    if 'actual_price' in df.columns:
        df['actual_price'] = df['actual_price'].replace('[^\d.]', '', regex=True)
        df['actual_price'] = pd.to_numeric(df['actual_price'], errors='coerce')  # Convert to numeric, kalau ada error dijadiin NaN
        df['actual_price'].fillna(0, inplace=True)  # ganti NaN dengan 0 
    
    # Delete simbol currency nya jadi cuma angka aja buat kolom discount price
    if 'discount_price' in df.columns:
        df['discount_price'] = df['discount_price'].replace('[^\d.]', '', regex=True)
        df['discount_price'] = pd.to_numeric(df['discount_price'], errors='coerce')  # Convert to float
        df['discount_price'].fillna(0, inplace=True)  # Replace NaN values with 0
    
    # Convert rating ke numeric
    if 'ratings' in df.columns:
        df['ratings'] = pd.to_numeric(df['ratings'], errors='coerce')  # Convert to numeric, kalau ada error dijadiin NaN
    
    # Transform the 'no_of_ratings' column
    if 'no_of_ratings' in df.columns:
    # Delete semua non numeric values, dan convert values nya ke numeric
        df['no_of_ratings'] = df['no_of_ratings'].replace('[^\d]', '', regex=True)
        df['no_of_ratings'] = pd.to_numeric(df['no_of_ratings'], errors='coerce').fillna(0)

    
    return df

# %%
# Fungsi untuk coba coba statistik simple
def basic_statistics(df):
    print("Basic Statistics:")
    print(df.describe())
    print("\n")

# Fungsi yang menganalisa values yang kosong
def missing_values_analysis(df):
    print("Missing Values Analysis:")
    missing_values = df.isnull().sum()
    missing_percentage = (missing_values / len(df)) * 100
    print(pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage}))
    print("\n")

# Fungsi menganalisa distribusi kategori
def categorical_distribution(df, column_name):
    if column_name in df.columns:
        print(f"Distribution of {column_name}:")
        print(df[column_name].value_counts())
        print("\n")

# Fungsi untuk aggregasi atau penjumlahan datanya
def numeric_aggregation(df, column_name):
    if column_name in df.columns and pd.api.types.is_numeric_dtype(df[column_name]):
        print(f"Total {column_name}: {df[column_name].sum()}")
        print(f"Average {column_name}: {df[column_name].mean()}")
        print("\n")

#Fungsi untuk ngedisplay top N values di kolomnya
def top_n_analysis(df, column_name, n=5):
    if column_name in df.columns:
        print(f"Top {n} based on {column_name}:")
        print(df.nlargest(n, column_name))
        print("\n")

# Fungsi korelasi analisis
def correlation_analysis(df):
    print("Correlation Matrix:")
    correlation = df.corr()
    print(correlation)
    print("\n")

# # Fungsi untuk deteksi outlier
# def outlier_detection(df, column_name, threshold):
#     if column_name in df.columns and pd.api.types.is_numeric_dtype(df[column_name]):
#         outliers = df[df[column_name] > threshold]
#         print(f"Number of outliers in {column_name} greater than {threshold}: {len(outliers)}")
#         print(outliers)
#         print("\n")

# Fungsi untuk cek datanya lengkap atau engga
def data_completeness(df):
    total_rows = df.shape[0]
    if total_rows == 0:
        print("The DataFrame is empty, data completeness cannot be calculated.")
    else:
        complete_rows = df.dropna().shape[0]
        completeness_percentage = (complete_rows / total_rows) * 100
        print(f"Percentage of complete rows: {completeness_percentage:.2f}%")
    print("\n")


# Fungsi top 3 product dengan rating tertinggi
def top_3_highest_rating(df):
    if 'ratings' in df.columns:
        print("Top 3 Products with the Highest Rating:")
        top_3_ratings = df.nlargest(3, 'ratings')
        print(top_3_ratings[['name', 'ratings']])
        print("\n")

# Fungsi top 3 product dengan rating terbanyak
def top_3_most_ratings(df):
    if 'no_of_ratings' in df.columns:
        print("Top 3 Products with the Most Ratings:")
        top_3_most = df.nlargest(3, 'no_of_ratings')
        print(top_3_most[['name', 'no_of_ratings']])
        print("\n")


# Funsgi untuk melihat product dengan rating terbanyak dan juga di sort dari yang tertinggi ratingannya buat top 3 aja
def top_3_most_ratings_sorted(df):
    if 'no_of_ratings' in df.columns:
        print("Top 3 Products with the Most Ratings, Sorted by Highest:")
        sorted_ratings = df.sort_values(by='no_of_ratings', ascending=False).head(3)
        print(sorted_ratings[['name', 'no_of_ratings']])
        print("\n")

# %%
# Fungsi ETL utama dan analisis demography 
def main():
    # Get the list of all CSV files in the source folder
    files = [file for file in os.listdir(source_folder_path) if file.endswith('.csv')]

    # Create output directory if it doesn't exist
    os.makedirs(output_folder_path, exist_ok=True)

    # Process tiap file
    for file in files:
        file_path = os.path.join(source_folder_path, file)
        
        # Step 1: Data Extraction
        df = extract_data(file_path)
        
        # Step 2: Data Transformation
        df = transform_data(df)
        
        # Step 3: Data Demography Analysis
        print(f"=== Analysis for {file} ===")
        print("=== Basic Statistics ===")
        basic_statistics(df)
        
        print("=== Missing Values Analysis ===")
        missing_values_analysis(df)
        
        # print("=== Categorical Data Distribution ===")
        # categorical_distribution(df, "category_column")  
        
        # print("=== Numeric Data Aggregation ===")
        # numeric_aggregation(df, "price_column")  
        
        # print("=== Top N Analysis ===")
        # top_n_analysis(df, "price_column", 5) 
        
        print("=== Correlation Analysis ===")
        correlation_analysis(df)
        
        # print("=== Outlier Detection ===")
        # outlier_detection(df, "price_column", 10000)  
        
        print("=== Data Completeness ===")
        data_completeness(df)
        
        print("=== Top 3 Products with the Highest Rating ===")
        top_3_highest_rating(df)
        
        print("=== Top 3 Products with the Most Ratings ===")
        top_3_most_ratings(df)
        
        print("=== Top 3 Products with the Most Ratings, Sorted ===")
        top_3_most_ratings_sorted(df)
        
        # Save the transformed data
        output_file_path = os.path.join(output_folder_path, f"Cleaned_{file}")
        df.to_csv(output_file_path, index=False)
        print(f"Transformed data saved for {file}.\n")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# === Analysis for Air Conditioners.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           ratings  no_of_ratings  discount_price   actual_price
# count  423.000000     720.000000      720.000000     720.000000
# mean     3.809693     144.087500    25868.743056   38066.130028
# std      0.789610     564.281521    22969.750811   31589.188305
# min      1.000000       0.000000        0.000000       0.000000
# 25%      3.500000       0.000000        0.000000       0.000000
# 50%      4.000000       2.000000    32999.000000   47045.000000
# 75%      4.200000      40.000000    41999.250000   61990.000000
# max      5.000000    9577.000000   128800.000000  149000.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0        0.00
# main_category                0        0.00
# sub_category                 0        0.00
# image                        0        0.00
# link                         0        0.00
# ratings                    297       41.25
# no_of_ratings                0        0.00
# discount_price               0        0.00
# actual_price                 0        0.00
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.091584        0.140578      0.179443
# no_of_ratings   0.091584       1.000000        0.042014      0.078818
# discount_price  0.140578       0.042014        1.000000      0.948824
# actual_price    0.179443       0.078818        0.948824      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 58.75%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                  name  ratings
# 58  Hitachi Split Ac - 1.5 Ton Kiyora 5200Fx I Fre...      5.0
# 89  Panasonic 2 Ton 5 Star Wi-Fi Inverter Smart Sp...      5.0
# 97  Panasonic 1.5 Ton 3 Star Hot and Cold Wi-Fi In...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                   name  no_of_ratings
# 237  Ontel Arctic Air Freedom Portable Personal Air...         9577.0
# 12   Panasonic 1.5 Ton 5 Star Wi-Fi Inverter Smart ...         5073.0
# 14   Whirlpool 1.5 Ton 3 Star, Flexicool Inverter S...         3670.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                   name  no_of_ratings
# 237  Ontel Arctic Air Freedom Portable Personal Air...         9577.0
# 12   Panasonic 1.5 Ton 5 Star Wi-Fi Inverter Smart ...         5073.0
# 14   Whirlpool 1.5 Ton 3 Star, Flexicool Inverter S...         3670.0
#
#
# Transformed data saved for Air Conditioners.csv.
#
# === Analysis for All Appliances.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price   actual_price
# count  9038.000000    9576.000000     9576.000000    9576.000000
# mean      3.926864     833.194131     3530.789425    5712.594854
# std       0.544413    4315.529179     7612.193059   11559.302349
# min       1.000000       0.000000        0.000000       0.000000
# 25%       3.700000      14.000000      339.000000     799.000000
# 50%       4.000000      88.000000      799.000000    1599.000000
# 75%       4.200000     435.000000     2876.250000    4795.750000
# max       5.000000  274505.000000    83990.000000  158490.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    538    5.618212
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.060954        0.114363      0.114453
# no_of_ratings   0.060954       1.000000        0.008429      0.003657
# discount_price  0.114363       0.008429        1.000000      0.964601
# actual_price    0.114453       0.003657        0.964601      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 94.38%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 419  PASHV ENTERPRISE Sewing Machine Electric Handh...      5.0
# 629  Samsung 236 L 2 Star Inverter Frost-Free Doubl...      5.0
# 708  GITGRNTH Mini Bag Sealer, Portable Heat Vacuum...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                    name  no_of_ratings
# 1     Pigeon Polypropylene Mini Handy and Compact Ch...       274505.0
# 0     Pigeon by Stovekraft Amaze Plus Electric Kettl...       128941.0
# 1949  Philips GC026 Electric Lint Removers/Clothes S...        95193.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                    name  no_of_ratings
# 1     Pigeon Polypropylene Mini Handy and Compact Ch...       274505.0
# 0     Pigeon by Stovekraft Amaze Plus Electric Kettl...       128941.0
# 1949  Philips GC026 Electric Lint Removers/Clothes S...        95193.0
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# Transformed data saved for All Appliances.csv.
#
# === Analysis for All Books.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All Books.csv.
#
# === Analysis for All Car and Motorbike Products.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  1214.000000    1272.000000     1272.000000   1272.000000
# mean      3.847364     660.659591      811.108892   1594.628931
# std       0.613631    3632.154577     1582.644496   2531.818027
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.600000      11.000000      238.750000    500.000000
# 50%       3.900000      63.000000      387.500000    999.000000
# 75%       4.200000     263.250000      799.000000   1599.000000
# max       5.000000   78970.000000    27007.000000  43399.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                     58    4.559748
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.081665        0.106460      0.095766
# no_of_ratings   0.081665       1.000000       -0.009697     -0.021556
# discount_price  0.106460      -0.009697        1.000000      0.929788
# actual_price    0.095766      -0.021556        0.929788      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 95.44%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 44   PRIVILION GLOBALE Portable High Pressure Washi...      5.0
# 74   Ns Ltd Genuine like Design Bar End Rear view M...      5.0
# 107  Cheston High Pressure Washer with Copper Windi...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                  name  no_of_ratings
# 0   SOFTSPUN Microfiber Cloth - 4 pcs - 40x40 cms ...        78970.0
# 27  AmazonBasics 16-Gauge Speaker Wire - 100 Feet,...        49838.0
# 16                           Vega Crux Black Helmet-M        47175.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                  name  no_of_ratings
# 0   SOFTSPUN Microfiber Cloth - 4 pcs - 40x40 cms ...        78970.0
# 27  AmazonBasics 16-Gauge Speaker Wire - 100 Feet,...        49838.0
# 16                           Vega Crux Black Helmet-M        47175.0
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# Transformed data saved for All Car and Motorbike Products.csv.
#
# === Analysis for All Electronics.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price   actual_price
# count  9481.000000    9600.000000     9600.000000    9600.000000
# mean      4.077576    8771.017396     2826.221698    4973.169204
# std       0.377189   27962.923548     8663.594724   12171.869818
# min       1.000000       0.000000        0.000000       0.000000
# 25%       3.900000     220.750000      270.000000     799.000000
# 50%       4.100000    1136.000000      499.000000    1399.500000
# 75%       4.300000    4992.000000     1499.000000    3299.000000
# max       5.000000  437651.000000   134999.000000  161999.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    119    1.239583
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.070297        0.076021      0.061182
# no_of_ratings   0.070297       1.000000       -0.008685     -0.006749
# discount_price  0.076021      -0.008685        1.000000      0.932614
# actual_price    0.061182      -0.006749        0.932614      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 98.76%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 667  Onsitego 1 Year Extended Warranty for Small Ho...      5.0
# 809  SD CASS® Hanging Car Rear View Mirror Mobile P...      5.0
# 982  ZEBRONICS Zeb- Haze 2.4GHz Wireless Mouse with...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                    name  no_of_ratings
# 470   Amazon Basics High-Speed HDMI Cable - 10 Feet ...       437651.0
# 605   Amazon Basics Flexible Premium HDMI Cable (Bla...       437651.0
# 1217  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...       437651.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                    name  no_of_ratings
# 1217  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...       437651.0
# 2542  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...       437651.0
# 470   Amazon Basics High-Speed HDMI Cable - 10 Feet ...       437651.0
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# Transformed data saved for All Electronics.csv.
#
# === Analysis for All English.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All English.csv.
#
# === Analysis for All Exercise and Fitness.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  1054.000000    1176.000000     1176.000000   1176.000000
# mean      3.904934     675.928571      912.781947   2142.932007
# std       0.571859    3053.464315     2283.152389   5179.891093
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.600000       5.000000      299.000000    749.000000
# 50%       4.000000      40.000000      498.500000   1099.000000
# 75%       4.200000     298.500000      799.000000   1800.000000
# max       5.000000   74871.000000    29990.000000  62480.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0     0.00000
# main_category                0     0.00000
# sub_category                 0     0.00000
# image                        0     0.00000
# link                         0     0.00000
# ratings                    122    10.37415
# no_of_ratings                0     0.00000
# discount_price               0     0.00000
# actual_price                 0     0.00000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.064219        0.085383      0.076798
# no_of_ratings   0.064219       1.000000        0.020925      0.029235
# discount_price  0.085383       0.020925        1.000000      0.964029
# actual_price    0.076798       0.029235        0.964029      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 89.63%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 74   OJS Yoga Mat for Women and Men with Strap And ...      5.0
# 119  POWRSOX 4 Pairs Sports Socks for Men Moisture-...      5.0
# 212  DM MART Beautiful Ankle Length No Show Low Cut...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                  name  no_of_ratings
# 39  AmazonBasics 13mm Extra Thick Yoga and Exercis...        74871.0
# 4   Kore PVC 10-40 Kg Home Gym Set with One 3 Ft C...        33078.0
# 84  Fitness Mantra® EVA Yoga Mat for Gym Workout a...        21710.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                  name  no_of_ratings
# 39  AmazonBasics 13mm Extra Thick Yoga and Exercis...        74871.0
# 4   Kore PVC 10-40 Kg Home Gym Set with One 3 Ft C...        33078.0
# 84  Fitness Mantra® EVA Yoga Mat for Gym Workout a...        21710.0
#
#
# Transformed data saved for All Exercise and Fitness.csv.
#
# === Analysis for All Grocery and Gourmet Foods.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           ratings  no_of_ratings  discount_price  actual_price
# count  945.000000     960.000000      960.000000    960.000000
# mean     4.176296     858.468750      306.051677    507.481250
# std      0.313788    1505.411989      625.974482   1389.228965
# min      2.000000       0.000000        0.000000      0.000000
# 25%      4.000000     109.000000       49.375000    170.000000
# 50%      4.200000     329.000000      193.000000    299.000000
# 75%      4.300000     906.000000      364.000000    500.000000
# max      5.000000   15528.000000    13899.000000  38000.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0      0.0000
# main_category                0      0.0000
# sub_category                 0      0.0000
# image                        0      0.0000
# link                         0      0.0000
# ratings                     15      1.5625
# no_of_ratings                0      0.0000
# discount_price               0      0.0000
# actual_price                 0      0.0000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.100033       -0.028596     -0.051753
# no_of_ratings   0.100033       1.000000        0.255876      0.240288
# discount_price -0.028596       0.255876        1.000000      0.917585
# actual_price   -0.051753       0.240288        0.917585      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 98.44%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 248                        Puro Healthy Turmeric, 200g      5.0
# 430  PRIME CULTIVATOR: Premium Dried Anjeer (Figs) ...      5.0
# 547  Orion Turtle Chips Party snack - Hot Lime 130g...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                   name  no_of_ratings
# 4    Tata Tea Gold | Assam teas with Gently Rolled ...        15528.0
# 102  MuscleBlaze High Protein Natural Peanut Butter...        14516.0
# 76   Lifelong LLM99 Foot, Calf and Leg Massager, (W...        11339.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                   name  no_of_ratings
# 4    Tata Tea Gold | Assam teas with Gently Rolled ...        15528.0
# 102  MuscleBlaze High Protein Natural Peanut Butter...        14516.0
# 76   Lifelong LLM99 Foot, Calf and Leg Massager, (W...        11339.0
#
#
# Transformed data saved for All Grocery and Gourmet Foods.csv.
#
# === Analysis for All Hindi.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All Hindi.csv.
#
# === Analysis for All Home and Kitchen.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  1215.000000    1224.000000     1224.000000   1224.000000
# mean      4.077778    3129.414216     1188.506585   2230.496087
# std       0.388106    7346.257250     3679.165512   6126.897111
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.900000     153.750000      225.000000    459.000000
# 50%       4.100000     774.500000      387.000000    902.500000
# 75%       4.300000    2748.250000      780.000000   1699.250000
# max       5.000000   99346.000000    44990.000000  78490.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                      9    0.735294
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.101061        0.066470      0.054349
# no_of_ratings   0.101061       1.000000        0.030531      0.015393
# discount_price  0.066470       0.030531        1.000000      0.973202
# actual_price    0.054349       0.015393        0.973202      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 99.26%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 126  TAPUJI® 2023 New 2 In 1 Dumpling Maker, Dumpli...      5.0
# 160  LUBELA oval shape mirror sticker for wall on t...      5.0
# 347  Voetex Zone Adhesive Nails Hooks for Wall With...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                   name  no_of_ratings
# 87   TP-Link Tapo 360° 3MP 2304 Full HD 1296P Video...        99346.0
# 54   Cello Checkers Plastic PET Canister Set, 18 Pi...        67514.0
# 550  Wakefit Mattress | 10 Years Warranty | Orthope...        65485.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                   name  no_of_ratings
# 87   TP-Link Tapo 360° 3MP 2304 Full HD 1296P Video...        99346.0
# 54   Cello Checkers Plastic PET Canister Set, 18 Pi...        67514.0
# 550  Wakefit Mattress | 10 Years Warranty | Orthope...        65485.0
#
#
# Transformed data saved for All Home and Kitchen.csv.
#
# === Analysis for All Movies and TV Shows.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All Movies and TV Shows.csv.
#
# === Analysis for All Music.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All Music.csv.
#
# === Analysis for All Pet Supplies.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           ratings  no_of_ratings  discount_price  actual_price
# count  610.000000     648.000000      648.000000    648.000000
# mean     4.008689     757.109568      596.350679   1046.474969
# std      0.589431    3007.990831      912.463248   1602.561002
# min      1.000000       0.000000        0.000000      0.000000
# 25%      3.725000       9.000000      208.645000    399.000000
# 50%      4.100000      49.000000      359.500000    600.000000
# 75%      4.300000     274.000000      664.500000   1099.000000
# max      5.000000   36349.000000    13536.390000  27072.780000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                     38    5.864198
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.104072        0.104075      0.092034
# no_of_ratings   0.104072       1.000000        0.050077      0.016984
# discount_price  0.104075       0.050077        1.000000      0.907365
# actual_price    0.092034       0.016984        0.907365      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 94.14%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 63   HUDACRUSH Dog Bath Brush Body Scrubber Shampoo...      5.0
# 129  Foodie Puppies Natural Soft Silicone Finger To...      5.0
# 231  klench Safest Round Organic Bird nest Purely H...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                   name  no_of_ratings
# 0    Meat Up Chicken Flavour Real Chicken Dog Biscu...        36349.0
# 168                       Kong Extreme Dog Toy (Large)        26827.0
# 124  Amazon Basics Pet Feeding Bowl 700 ml, Blue (S...        25130.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                   name  no_of_ratings
# 0    Meat Up Chicken Flavour Real Chicken Dog Biscu...        36349.0
# 168                       Kong Extreme Dog Toy (Large)        26827.0
# 124  Amazon Basics Pet Feeding Bowl 700 ml, Blue (S...        25130.0
#
#
# Transformed data saved for All Pet Supplies.csv.
#
# === Analysis for All Sports Fitness and Outdoors.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  1167.000000    1224.000000     1224.000000   1224.000000
# mean      3.879263     616.233660     1132.098252   2372.760417
# std       0.525685    2264.945879     3016.443877   5697.274819
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.650000      18.000000      299.000000    699.000000
# 50%       3.900000      76.500000      499.000000    999.000000
# 75%       4.100000     382.500000      901.500000   1999.000000
# max       5.000000   44728.000000    41999.000000  79000.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                     57    4.656863
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.082898        0.085323      0.068504
# no_of_ratings   0.082898       1.000000        0.001880     -0.011705
# discount_price  0.085323       0.001880        1.000000      0.923829
# actual_price    0.068504      -0.011705        0.923829      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 95.34%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 17   Volatility Russia Hand Stich Football Size-05 ...      5.0
# 61   Bodyband Yoga Mat for Women and Men 4mm with C...      5.0
# 200  TDTC Stainless Steel Inflating Pump Needle Pin...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                           name  no_of_ratings
# 148  AmazonBasics Neoprene Dumbbells, Set of 2        44728.0
# 0         Campus Men's OXYFIT (N) Walking Shoe        30227.0
# 39           Campus Men's Maxico Running Shoes        20427.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                           name  no_of_ratings
# 148  AmazonBasics Neoprene Dumbbells, Set of 2        44728.0
# 0         Campus Men's OXYFIT (N) Walking Shoe        30227.0
# 39           Campus Men's Maxico Running Shoes        20427.0
#
#
# Transformed data saved for All Sports Fitness and Outdoors.csv.
#
# === Analysis for All Video Games.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for All Video Games.csv.
#
# === Analysis for Amazon Fashion.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  2142.000000    2352.000000     2352.000000   2352.000000
# mean      4.019001    2757.939626      842.282092   1929.581565
# std       0.368592    7878.832416     1977.581079   3119.690795
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.800000      59.000000      234.500000    599.000000
# 50%       4.100000     485.000000      398.000000   1018.500000
# 75%       4.200000    2141.000000      829.500000   2096.000000
# max       5.000000  157480.000000    64644.000000  72800.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    210    8.928571
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.084901        0.120537      0.078588
# no_of_ratings   0.084901       1.000000       -0.013662     -0.041432
# discount_price  0.120537      -0.013662        1.000000      0.823060
# actual_price    0.078588      -0.041432        0.823060      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 91.07%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 299  Saanchi Ecommerce Women's Georgette Sarees ($$...      5.0
# 329  DIY Crafts Watch Spring Bars, 360Pcs 8-25mm Pr...      5.0
# 461   Trolls: Water-Color!: Talent Show (Media Tie-In)      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                    name  no_of_ratings
# 1112              crocs Unisex Crocband Clogs and Mules       157480.0
# 41    Pigeon by Stovekraft Amaze Plus Electric Kettl...       129025.0
# 6     Noise ColorFit Pulse Grand Smart Watch with 1....        99745.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                    name  no_of_ratings
# 1112              crocs Unisex Crocband Clogs and Mules       157480.0
# 41    Pigeon by Stovekraft Amaze Plus Electric Kettl...       129025.0
# 6     Noise ColorFit Pulse Grand Smart Watch with 1....        99745.0
#
#
# Transformed data saved for Amazon Fashion.csv.
#
# === Analysis for Amazon Pharmacy.csv ===
# === Basic Statistics ===
# Basic Statistics:
#        ratings  no_of_ratings  discount_price  actual_price
# count      0.0            0.0             0.0           0.0
# mean       NaN            NaN             NaN           NaN
# std        NaN            NaN             NaN           NaN
# min        NaN            NaN             NaN           NaN
# 25%        NaN            NaN             NaN           NaN
# 50%        NaN            NaN             NaN           NaN
# 75%        NaN            NaN             NaN           NaN
# max        NaN            NaN             NaN           NaN
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                       0.0         NaN
# main_category              0.0         NaN
# sub_category               0.0         NaN
# image                      0.0         NaN
# link                       0.0         NaN
# ratings                    0.0         NaN
# no_of_ratings              0.0         NaN
# discount_price             0.0         NaN
# actual_price               0.0         NaN
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                 ratings  no_of_ratings  discount_price  actual_price
# ratings             NaN            NaN             NaN           NaN
# no_of_ratings       NaN            NaN             NaN           NaN
# discount_price      NaN            NaN             NaN           NaN
# actual_price        NaN            NaN             NaN           NaN
#
#
# === Data Completeness ===
# The DataFrame is empty, data completeness cannot be calculated.
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
# Empty DataFrame
# Columns: [name, ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
# Empty DataFrame
# Columns: [name, no_of_ratings]
# Index: []
#
#
# Transformed data saved for Amazon Pharmacy.csv.
#
# === Analysis for Amazon-Products.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           Unnamed: 0        ratings  no_of_ratings  discount_price  \
# ...
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# === Analysis for Washing Machines.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           ratings  no_of_ratings  discount_price   actual_price
# count  633.000000    1440.000000     1440.000000    1440.000000
# mean     3.981201     161.206944    10883.757271   16135.267931
# std      0.806958     956.951010    15533.087389   24303.569386
# min      1.000000       0.000000        0.000000       0.000000
# 25%      3.800000       0.000000        0.000000     578.750000
# 50%      4.200000       0.000000     3999.000000    9999.000000
# 75%      4.400000      12.000000    17409.250000   23922.500000
# max      5.000000   24086.000000   230000.000000  600000.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    807   56.041667
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.089097        0.067595      0.088096
# no_of_ratings   0.089097       1.000000        0.069026      0.049404
# discount_price  0.067595       0.069026        1.000000      0.910037
# actual_price    0.088096       0.049404        0.910037      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 43.96%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                  name  ratings
# 19  OCTRA Mini Foldable Top Load Washing Machine P...      5.0
# 64  Shankar Mini Folding Washing Machine Foldable ...      5.0
# 71  Riyan Latest Mini Washing Machine Portable Fol...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                 name  no_of_ratings
# 0  Samsung 7 kg Fully-Automatic Top Loading Washi...        24086.0
# 3  LG 7 Kg 5 Star Inverter Fully-Automatic Top Lo...        13541.0
# 9  Whirlpool 7 Kg 5 Star Semi-Automatic Top Loadi...        10025.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                 name  no_of_ratings
# 0  Samsung 7 kg Fully-Automatic Top Loading Washi...        24086.0
# 3  LG 7 Kg 5 Star Inverter Fully-Automatic Top Lo...        13541.0
# 9  Whirlpool 7 Kg 5 Star Semi-Automatic Top Loadi...        10025.0
#
#
# Transformed data saved for Washing Machines.csv.
#
# === Analysis for Watches.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price   actual_price
# count  8597.000000   19133.000000    19133.000000   19133.000000
# mean      3.838258      59.799038     1700.987526    3933.333654
# std       0.900548    1083.128589     4108.386003    6297.151773
# min       1.000000       0.000000        0.000000       0.000000
# 25%       3.400000       0.000000      262.000000     899.000000
# 50%       4.000000       0.000000      369.000000    1308.000000
# 75%       4.400000       5.000000     1049.000000    4465.000000
# max       5.000000  142023.000000    83650.000000  113750.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                  10536   55.067161
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.071824        0.156770      0.215295
# no_of_ratings   0.071824       1.000000        0.029522      0.032975
# discount_price  0.156770       0.029522        1.000000      0.750607
# actual_price    0.215295       0.032975        0.750607      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 44.93%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 140     Titan Analog Brown Dial Women's Watch-2608QM02      5.0
# 158  CLOUDWOOD Digital Vintage Square Dial Unisex W...      5.0
# 238  Armani Exchange Hampton Analog Rose Gold Dial ...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                     name  no_of_ratings
# 13597  Fossil Raquel Analog White Dial Women's Watch-...       142023.0
# 10835               Nike Women WMNS Tanjun Running Shoes        13838.0
# 1      Fossil Gen 5E Smartwatch with AMOLED Screen, W...        12329.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                     name  no_of_ratings
# 13597  Fossil Raquel Analog White Dial Women's Watch-...       142023.0
# 10835               Nike Women WMNS Tanjun Running Shoes        13838.0
# 1      Fossil Gen 5E Smartwatch with AMOLED Screen, W...        12329.0
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# Transformed data saved for Watches.csv.
#
# === Analysis for Western Wear.csv ===
# === Basic Statistics ===
# Basic Statistics:
#             ratings  no_of_ratings  discount_price  actual_price
# count  15646.000000   19200.000000    19200.000000  19200.000000
# mean       3.774102     115.528542      605.543257   1616.823514
# std        0.722897     490.934025      464.262938   1031.958070
# min        1.000000       0.000000        0.000000      0.000000
# 25%        3.400000       1.000000      349.000000    999.000000
# 50%        3.800000       8.000000      499.000000   1400.000000
# 75%        4.100000      48.000000      750.000000   1999.000000
# max        5.000000   25809.000000    14098.000000  49999.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                   3554   18.510417
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.031963        0.028750      0.027216
# no_of_ratings   0.031963       1.000000       -0.047253     -0.024422
# discount_price  0.028750      -0.047253        1.000000      0.676210
# actual_price    0.027216      -0.024422        0.676210      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 81.49%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 22               CALM DOWN Oversized T-Shirt for Women      5.0
# 71   SYYNCRO Women's Western Bodycon Dresses for Wo...      5.0
# 150  JUNEBERRY® Oversized Loose Baggy Fit Drop Shoo...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                        name  no_of_ratings
# 50      Amazon Brand - Symbol Women T-Shirt        25809.0
# 585  FLEXIMAA Women's Cotton Hooded Hoodies        12805.0
# 136        Harpa Round Neck Printed Dresses        12377.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                        name  no_of_ratings
# 50      Amazon Brand - Symbol Women T-Shirt        25809.0
# 585  FLEXIMAA Women's Cotton Hooded Hoodies        12805.0
# 136        Harpa Round Neck Printed Dresses        12377.0
#
#
# Transformed data saved for Western Wear.csv.
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# === Analysis for Womens Fashion.csv ===
# === Basic Statistics ===
# Basic Statistics:
#            ratings  no_of_ratings  discount_price  actual_price
# count  1873.000000    2112.000000     2112.000000   2112.000000
# mean      3.909130     429.457860      811.657401   2187.363480
# std       0.527195    2111.540106     2229.037946   3063.651103
# min       1.000000       0.000000        0.000000      0.000000
# 25%       3.600000       7.000000      289.000000    999.000000
# 50%       3.900000      51.000000      469.000000   1499.000000
# 75%       4.200000     288.000000      799.000000   2499.000000
# max       5.000000   67255.000000    64111.000000  70522.100000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    239   11.316288
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.042088        0.110538      0.131895
# no_of_ratings   0.042088       1.000000       -0.005933      0.006034
# discount_price  0.110538      -0.005933        1.000000      0.795083
# actual_price    0.131895       0.006034        0.795083      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 88.68%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                   name  ratings
# 219  Carrylux Handbags For Womens Fashion Top Handl...      5.0
# 223                        Elegant BTS Watch for Girls      5.0
# 244               Baggit Women's Tote Handbag - Medium      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                name  no_of_ratings
# 758                 crocs Unisex-Adult Classic Clog        67255.0
# 1838  Skechers Women's Go Walk 5-Brave Walking Shoe        55051.0
# 89                           FLITE Women Flip-Flops        15467.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                name  no_of_ratings
# 758                 crocs Unisex-Adult Classic Clog        67255.0
# 1838  Skechers Women's Go Walk 5-Brave Walking Shoe        55051.0
# 89                           FLITE Women Flip-Flops        15467.0
#
#
# Transformed data saved for Womens Fashion.csv.
#
# === Analysis for Yoga.csv ===
# === Basic Statistics ===
# Basic Statistics:
#           ratings  no_of_ratings  discount_price  actual_price
# count  836.000000    1104.000000     1104.000000   1104.000000
# mean     3.863636     106.480072      815.859801   1755.082219
# std      0.708642     533.758707      900.931882   1905.429429
# min      1.000000       0.000000        0.000000      0.000000
# 25%      3.500000       1.000000      383.750000    999.000000
# 50%      3.900000       6.000000      653.005000   1499.000000
# 75%      4.300000      28.000000      976.000000   1999.000000
# max      5.000000    9596.000000    16614.000000  43400.000000
#
#
# === Missing Values Analysis ===
# Missing Values Analysis:
#                 Missing Values  Percentage
# name                         0    0.000000
# main_category                0    0.000000
# sub_category                 0    0.000000
# image                        0    0.000000
# link                         0    0.000000
# ratings                    268   24.275362
# no_of_ratings                0    0.000000
# discount_price               0    0.000000
# actual_price                 0    0.000000
#
#
# === Correlation Analysis ===
# Correlation Matrix:
#                  ratings  no_of_ratings  discount_price  actual_price
# ratings         1.000000       0.080721        0.113419      0.097137
# no_of_ratings   0.080721       1.000000        0.022100      0.064818
# discount_price  0.113419       0.022100        1.000000      0.863021
# actual_price    0.097137       0.064818        0.863021      1.000000
#
#
# === Data Completeness ===
# Percentage of complete rows: 75.72%
#
#
# === Top 3 Products with the Highest Rating ===
# Top 3 Products with the Highest Rating:
#                                                  name  ratings
# 81  Wiselife Play & Exercise 6MM Kids Printed Yoga...      5.0
# 91  Estacell Yoga Mat Strap for Carrying, Adjustab...      5.0
# 93  The Black Bee Running Quick Dry Shorts for Men...      5.0
#
#
# === Top 3 Products with the Most Ratings ===
# Top 3 Products with the Most Ratings:
#                                                   name  no_of_ratings
# 178   Russell Athletic Men's Essential Long Sleeve Tee         9596.0
# 342                                adidas Training Mat         7141.0
# 107  Jockey 1301 Women's Super Combed Cotton Elasta...         6484.0
#
#
# === Top 3 Products with the Most Ratings, Sorted ===
# Top 3 Products with the Most Ratings, Sorted by Highest:
#                                                   name  no_of_ratings
# 178   Russell Athletic Men's Essential Long Sleeve Tee         9596.0
# 342                                adidas Training Mat         7141.0
# 107  Jockey 1301 Women's Super Combed Cotton Elasta...         6484.0
#
#
# Transformed data saved for Yoga.csv.
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# C:\Users\N I T R O   5\AppData\Local\Temp\ipykernel_37400\801549112.py:39: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
